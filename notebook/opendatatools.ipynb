# %% [markdown]
# # 开源爬虫工具OpenDataTools及其使用样例

# %% [markdown]
# ## 项目介绍
#
# + OpenDataTools是一个开源爬虫工具,通过爬虫将各种数据接口简化,方便用户使用. 由QuantOS团队开发.
#
# + 目前的版本是:0.0.5
#
# + 目前只支持 空气质量AQI 的数据获取.
#
# + 项目地址: https://github.com/PKUJohnson/OpenData, 感兴趣的同学可以去研究代码.

# %% [markdown]
# ## 样例介绍
#
# 空气质量数据AQI, 数据来源于 环保部网站. http://datacenter.mep.gov.cn/

# %% [markdown]
# ## 准备工作
#
# 安装opendatatools(开源的数据爬虫工具)
# + pip install opendatatools
#
# 安装pyecharts
# + pip install pyecharts
# + pip install echarts-countries-pypkg
# + pip install echarts-china-provinces-pypkg
# + pip install echarts-china-cities-pypkg

# %% [markdown]
# ## Case 1: API介绍(OpenDataTools获取空气质量数据)

# %%
from opendatatools import aqi

# %%
# 获取历史某日全国各大城市的AQI数据
# 返回DataFrame
df_aqi = aqi.get_daily_aqi('2018-05-27')
df_aqi
# Out:
#      aqi    city    code        date  indicator level
# 0     90     北京市  110000  2018-05-27  颗粒物(PM10)     良
# 1     99     天津市  120000  2018-05-27  颗粒物(PM10)     良
# 2     89    石家庄市  130100  2018-05-27  颗粒物(PM10)     良
# 3    104     唐山市  130200  2018-05-27  颗粒物(PM10)  轻度污染
# 4     95    秦皇岛市  130300  2018-05-27      臭氧8小时     良
# 5    101     邯郸市  130400  2018-05-27      臭氧8小时  轻度污染
# 6     88     邢台市  130500  2018-05-27  颗粒物(PM10)     良
# 7     97     保定市  130600  2018-05-27      臭氧8小时     良
# 8     82     承德市  130800  2018-05-27  颗粒物(PM10)     良
# 9    100     沧州市  130900  2018-05-27      臭氧8小时     良
# 10    84     廊坊市  131000  2018-05-27  颗粒物(PM10)     良
# 11    90     衡水市  131100  2018-05-27      臭氧8小时     良
# 12   203    张家口市  131200  2018-05-27  颗粒物(PM10)  重度污染
# 13   117     太原市  140100  2018-05-27  颗粒物(PM10)  轻度污染
# 14    87     大同市  140200  2018-05-27  颗粒物(PM10)     良
# 15    90     阳泉市  140300  2018-05-27      臭氧8小时     良
# 16    90     长治市  140400  2018-05-27      臭氧8小时     良
# 17    95     晋城市  140500  2018-05-27      臭氧8小时     良
# 18    87     朔州市  140600  2018-05-27  颗粒物(PM10)     良
# 19   108     晋中市  140700  2018-05-27  颗粒物(PM10)  轻度污染
# 20    98     运城市  140800  2018-05-27  颗粒物(PM10)     良
# 21    76     忻州市  140900  2018-05-27      臭氧8小时     良
# 22   110     临汾市  141000  2018-05-27      臭氧8小时  轻度污染
# 23    73     吕梁市  141100  2018-05-27      臭氧8小时     良
# 24    88   呼和浩特市  150100  2018-05-27  颗粒物(PM10)     良
# 25    89     包头市  150200  2018-05-27  颗粒物(PM10)     良
# 26    76     乌海市  150300  2018-05-27      臭氧8小时     良
# 27    78     赤峰市  150400  2018-05-27  颗粒物(PM10)     良
# 28    67     通辽市  150500  2018-05-27      臭氧8小时     良
# 29    82   鄂尔多斯市  150600  2018-05-27      臭氧8小时     良
# ..   ...     ...     ...         ...        ...   ...
# 337   93     甘南州  623000  2018-05-27      臭氧8小时     良
# 338  111     西宁市  630100  2018-05-27  颗粒物(PM10)  轻度污染
# 339   92    海东地区  632100  2018-05-27  颗粒物(PM10)     良
# 340   85     海北州  632200  2018-05-27      臭氧8小时     良
# 341   81     黄南州  632300  2018-05-27  颗粒物(PM10)     良
# 342   83     海南州  632500  2018-05-27  颗粒物(PM10)     良
# 343  103     果洛州  632600  2018-05-27  颗粒物(PM10)  轻度污染
# 344   59     玉树州  632700  2018-05-27  颗粒物(PM10)     良
# 345   73     海西州  632800  2018-05-27      臭氧8小时     良
# 346   79     银川市  640100  2018-05-27  颗粒物(PM10)     良
# 347   95    石嘴山市  640200  2018-05-27  颗粒物(PM10)     良
# 348   97     吴忠市  640300  2018-05-27  颗粒物(PM10)     良
# 349  109     固原市  640400  2018-05-27  颗粒物(PM10)  轻度污染
# 350   93     中卫市  640500  2018-05-27  颗粒物(PM10)     良
# 351   91   乌鲁木齐市  650100  2018-05-27  颗粒物(PM10)     良
# 352   85   克拉玛依市  650200  2018-05-27      臭氧8小时     良
# 353  128   吐鲁番地区  652100  2018-05-27  颗粒物(PM10)  轻度污染
# 354   75    哈密地区  652200  2018-05-27      臭氧8小时     良
# 355   82     昌吉州  652300  2018-05-27  颗粒物(PM10)     良
# 356   73      博州  652700  2018-05-27      臭氧8小时     良
# 357  464    库尔勒市  652800  2018-05-27  颗粒物(PM10)  严重污染
# 358  212   阿克苏地区  652900  2018-05-27  颗粒物(PM10)  重度污染
# 359  305      克州  653000  2018-05-27  颗粒物(PM10)  严重污染
# 360  420    喀什地区  653100  2018-05-27  颗粒物(PM10)  严重污染
# 361  258    和田地区  653200  2018-05-27  颗粒物(PM10)  重度污染
# 362   75  伊犁哈萨克州  654000  2018-05-27      臭氧8小时     良
# 363   52    塔城地区  654200  2018-05-27      臭氧8小时     良
# 364   70   阿勒泰地区  654300  2018-05-27      臭氧8小时     良
# 365  108    石河子市  659001  2018-05-27      臭氧8小时  轻度污染
# 366   78    五家渠市  659004  2018-05-27      臭氧8小时     良
#
# [367 rows x 6 columns]

# %%
# 获取实时全国各大城市的AQI数据
#df_aqi = aqi.get_hour_aqi('2018-05-28 11:00:00')

# 如果不指定时间点,会尝试获取最近的数据
df_aqi = aqi.get_hour_aqi()
df_aqi
# Out:
#      aqi    city    code    indicator level                 time
# 0     69     北京市  110000    颗粒物(PM10)     良  2018-05-28 12:00:00
# 1    367     天津市  120000    颗粒物(PM10)  严重污染  2018-05-28 12:00:00
# 2     73    石家庄市  130100    颗粒物(PM10)     良  2018-05-28 12:00:00
# 3    249     唐山市  130200    颗粒物(PM10)  重度污染  2018-05-28 12:00:00
# 4     88    秦皇岛市  130300    颗粒物(PM10)     良  2018-05-28 12:00:00
# 5     65     邯郸市  130400        臭氧1小时     良  2018-05-28 12:00:00
# 6     93     邢台市  130500    颗粒物(PM10)     良  2018-05-28 12:00:00
# 7    126     保定市  130600    颗粒物(PM10)  轻度污染  2018-05-28 12:00:00
# 8     60     承德市  130800    颗粒物(PM10)     良  2018-05-28 12:00:00
# 9    176     沧州市  130900    颗粒物(PM10)  中度污染  2018-05-28 12:00:00
# 10   114     廊坊市  131000    颗粒物(PM10)  轻度污染  2018-05-28 12:00:00
# 11   121     衡水市  131100    颗粒物(PM10)  轻度污染  2018-05-28 12:00:00
# 12    31    张家口市  131200                  优  2018-05-28 12:00:00
# 13   136     太原市  140100    颗粒物(PM10)  轻度污染  2018-05-28 12:00:00
# 14   135     大同市  140200    颗粒物(PM10)  轻度污染  2018-05-28 12:00:00
# 15    72     阳泉市  140300    颗粒物(PM10)     良  2018-05-28 12:00:00
# 16    74     长治市  140400    颗粒物(PM10)     良  2018-05-28 12:00:00
# 17    76     晋城市  140500    颗粒物(PM10)     良  2018-05-28 12:00:00
# 18    70     朔州市  140600    颗粒物(PM10)     良  2018-05-28 12:00:00
# 19   112     晋中市  140700    颗粒物(PM10)  轻度污染  2018-05-28 12:00:00
# 20   104     运城市  140800    颗粒物(PM10)  轻度污染  2018-05-28 12:00:00
# 21    80     忻州市  140900    颗粒物(PM10)     良  2018-05-28 12:00:00
# 22   130     临汾市  141000    颗粒物(PM10)  轻度污染  2018-05-28 12:00:00
# 23    74     吕梁市  141100    颗粒物(PM10)     良  2018-05-28 12:00:00
# 24    42   呼和浩特市  150100                  优  2018-05-28 12:00:00
# 25   137     包头市  150200    颗粒物(PM10)  轻度污染  2018-05-28 12:00:00
# 26   135     乌海市  150300  细颗粒物(PM2.5)  轻度污染  2018-05-28 12:00:00
# 27    46     赤峰市  150400                  优  2018-05-28 12:00:00
# 28    34     通辽市  150500                  优  2018-05-28 12:00:00
# 29    70   鄂尔多斯市  150600    颗粒物(PM10)     良  2018-05-28 12:00:00
# ..   ...     ...     ...          ...   ...                  ...
# 337   65     甘南州  623000    颗粒物(PM10)     良  2018-05-28 12:00:00
# 338  118     西宁市  630100    颗粒物(PM10)  轻度污染  2018-05-28 12:00:00
# 339   73    海东地区  632100    颗粒物(PM10)     良  2018-05-28 12:00:00
# 340   70     海北州  632200    颗粒物(PM10)     良  2018-05-28 12:00:00
# 341   63     黄南州  632300    颗粒物(PM10)     良  2018-05-28 12:00:00
# 342   73     海南州  632500    颗粒物(PM10)     良  2018-05-28 12:00:00
# 343   51     果洛州  632600    颗粒物(PM10)     良  2018-05-28 12:00:00
# 344   29     玉树州  632700                  优  2018-05-28 12:00:00
# 345   69     海西州  632800    颗粒物(PM10)     良  2018-05-28 12:00:00
# 346   85     银川市  640100    颗粒物(PM10)     良  2018-05-28 12:00:00
# 347   66    石嘴山市  640200    颗粒物(PM10)     良  2018-05-28 12:00:00
# 348   83     吴忠市  640300    颗粒物(PM10)     良  2018-05-28 12:00:00
# 349   67     固原市  640400    颗粒物(PM10)     良  2018-05-28 12:00:00
# 350   91     中卫市  640500    颗粒物(PM10)     良  2018-05-28 12:00:00
# 351  173   乌鲁木齐市  650100    颗粒物(PM10)  中度污染  2018-05-28 12:00:00
# 352   59   克拉玛依市  650200    颗粒物(PM10)     良  2018-05-28 12:00:00
# 353  409   吐鲁番地区  652100    颗粒物(PM10)  严重污染  2018-05-28 12:00:00
# 354   59    哈密地区  652200    颗粒物(PM10)     良  2018-05-28 12:00:00
# 355  129     昌吉州  652300    颗粒物(PM10)  轻度污染  2018-05-28 12:00:00
# 356   65      博州  652700    颗粒物(PM10)     良  2018-05-28 12:00:00
# 357  368    库尔勒市  652800    颗粒物(PM10)  严重污染  2018-05-28 12:00:00
# 358  260   阿克苏地区  652900    颗粒物(PM10)  重度污染  2018-05-28 12:00:00
# 359  222      克州  653000    颗粒物(PM10)  重度污染  2018-05-28 12:00:00
# 360  209    喀什地区  653100    颗粒物(PM10)  重度污染  2018-05-28 12:00:00
# 361  260    和田地区  653200    颗粒物(PM10)  重度污染  2018-05-28 12:00:00
# 362   76  伊犁哈萨克州  654000    颗粒物(PM10)     良  2018-05-28 12:00:00
# 363   62    塔城地区  654200    颗粒物(PM10)     良  2018-05-28 12:00:00
# 364   41   阿勒泰地区  654300                  优  2018-05-28 12:00:00
# 365   70    石河子市  659001    颗粒物(PM10)     良  2018-05-28 12:00:00
# 366  118    五家渠市  659004    颗粒物(PM10)  轻度污染  2018-05-28 12:00:00
#
# [367 rows x 6 columns]

# %%
# 获取单个城市的AQI历史数据
aqi.get_daily_aqi_onecity('北京市')
# Out:
#       aqi        date    indicator level
# 0      90  2018-05-27    颗粒物(PM10)     良
# 1     133  2018-05-26  细颗粒物(PM2.5)  轻度污染
# 2     162  2018-05-25        臭氧8小时  中度污染
# 3     151  2018-05-24        臭氧8小时  中度污染
# 4     138  2018-05-23    颗粒物(PM10)  轻度污染
# 5     135  2018-05-22    颗粒物(PM10)  轻度污染
# 6      83  2018-05-21  细颗粒物(PM2.5)     良
# 7      63  2018-05-20        臭氧8小时     良
# 8     110  2018-05-19        臭氧8小时  轻度污染
# 9      94  2018-05-18        臭氧8小时     良
# 10     59  2018-05-17  细颗粒物(PM2.5)     良
# 11    150  2018-05-16  细颗粒物(PM2.5)  轻度污染
# 12     92  2018-05-15  细颗粒物(PM2.5)     良
# 13    178  2018-05-14        臭氧8小时  中度污染
# 14    119  2018-05-13        臭氧8小时  轻度污染
# 15    185  2018-05-12  细颗粒物(PM2.5)  中度污染
# 16    108  2018-05-11  细颗粒物(PM2.5)  轻度污染
# 17    146  2018-05-10        臭氧8小时  轻度污染
# 18    120  2018-05-09        臭氧8小时  轻度污染
# 19     91  2018-05-08        臭氧8小时     良
# 20    104  2018-05-07        臭氧8小时  轻度污染
# 21    120  2018-05-06    颗粒物(PM10)  轻度污染
# 22     58  2018-05-03        臭氧8小时     良
# 23     51  2018-05-02        臭氧8小时     良
# 24    117  2018-05-01    颗粒物(PM10)  轻度污染
# 25     69  2018-04-30        臭氧8小时     良
# 26    204  2018-04-29  细颗粒物(PM2.5)  重度污染
# 27    150  2018-04-28        臭氧8小时  轻度污染
# 28    110  2018-04-27    颗粒物(PM10)  轻度污染
# 29    120  2018-04-26  细颗粒物(PM2.5)  轻度污染
# ...   ...         ...          ...   ...
# 1276  293  2014-11-26  细颗粒物(PM2.5)  重度污染
# 1277  196  2014-11-25  细颗粒物(PM2.5)  中度污染
# 1278   94  2014-11-24  细颗粒物(PM2.5)     良
# 1279  155  2014-11-23  细颗粒物(PM2.5)  中度污染
# 1280   74  2014-11-22         二氧化氮     良
# 1281  222  2014-11-21  细颗粒物(PM2.5)  重度污染
# 1282  351  2014-11-20  细颗粒物(PM2.5)  严重污染
# 1283  282  2014-11-19  细颗粒物(PM2.5)  重度污染
# 1284   93  2014-11-18         二氧化氮     良
# 1285   64  2014-11-17         二氧化氮     良
# 1286   34  2014-11-02                  优
# 1287  331  2014-03-26  细颗粒物(PM2.5)  严重污染
# 1288  404  2014-02-25  细颗粒物(PM2.5)  严重污染
# 1289  313  2014-02-24  细颗粒物(PM2.5)  严重污染
# 1290  255  2014-02-23  细颗粒物(PM2.5)  重度污染
# 1291  305  2014-02-22  细颗粒物(PM2.5)  严重污染
# 1292  311  2014-02-21  细颗粒物(PM2.5)  严重污染
# 1293  270  2014-02-20  细颗粒物(PM2.5)  重度污染
# 1294  429  2014-02-15  细颗粒物(PM2.5)  严重污染
# 1295  329  2014-02-14  细颗粒物(PM2.5)  严重污染
# 1296  242  2014-02-13  细颗粒物(PM2.5)  重度污染
# 1297  150  2014-02-12  细颗粒物(PM2.5)  轻度污染
# 1298  142  2014-02-11  细颗粒物(PM2.5)  轻度污染
# 1299   53  2014-02-10         二氧化氮     良
# 1300   34  2014-02-09                  优
# 1301   84  2014-02-08  细颗粒物(PM2.5)     良
# 1302  158  2014-02-06  细颗粒物(PM2.5)  中度污染
# 1303   47  2014-02-04                  优
# 1304   85  2014-02-02  细颗粒物(PM2.5)     良
# 1305  178  2014-02-01  细颗粒物(PM2.5)  中度污染
#
# [1306 rows x 4 columns]

# %%
#获取单个城市某日的AQI小时数据
aqi_hour = aqi.get_hour_aqi_onecity('北京市', '2018-05-26')
aqi_hour.set_index('time', inplace=True)
aqi_hour
# Out:
#                      aqi city    indicator level
# time
# 2018-05-26 23:00:00   88  北京市  细颗粒物(PM2.5)     良
# 2018-05-26 22:00:00   91  北京市    颗粒物(PM10)     良
# 2018-05-26 21:00:00  100  北京市    颗粒物(PM10)     良
# 2018-05-26 20:00:00  119  北京市    颗粒物(PM10)  轻度污染
# 2018-05-26 19:00:00  137  北京市    颗粒物(PM10)  轻度污染
# 2018-05-26 18:00:00  165  北京市    颗粒物(PM10)  中度污染
# 2018-05-26 17:00:00  144  北京市    颗粒物(PM10)  轻度污染
# 2018-05-26 16:00:00  178  北京市  细颗粒物(PM2.5)  中度污染
# 2018-05-26 15:00:00  178  北京市  细颗粒物(PM2.5)  中度污染
# 2018-05-26 14:00:00  183  北京市  细颗粒物(PM2.5)  中度污染
# 2018-05-26 13:00:00  192  北京市  细颗粒物(PM2.5)  中度污染
# 2018-05-26 12:00:00  188  北京市  细颗粒物(PM2.5)  中度污染
# 2018-05-26 11:00:00  185  北京市  细颗粒物(PM2.5)  中度污染
# 2018-05-26 10:00:00  180  北京市  细颗粒物(PM2.5)  中度污染
# 2018-05-26 09:00:00  170  北京市  细颗粒物(PM2.5)  中度污染
# 2018-05-26 08:00:00  156  北京市  细颗粒物(PM2.5)  中度污染
# 2018-05-26 07:00:00  144  北京市  细颗粒物(PM2.5)  轻度污染
# 2018-05-26 06:00:00  133  北京市  细颗粒物(PM2.5)  轻度污染
# 2018-05-26 05:00:00  128  北京市  细颗粒物(PM2.5)  轻度污染
# 2018-05-26 04:00:00  125  北京市  细颗粒物(PM2.5)  轻度污染
# 2018-05-26 03:00:00  119  北京市  细颗粒物(PM2.5)  轻度污染
# 2018-05-26 02:00:00  113  北京市  细颗粒物(PM2.5)  轻度污染
# 2018-05-26 01:00:00  105  北京市  细颗粒物(PM2.5)  轻度污染
# 2018-05-26 00:00:00   96  北京市    颗粒物(PM10)     良

# %% [markdown]
# ## Case 2 : 获取实时全国AQI数据并画地图展示

# %%
# encoding: utf-8

from opendatatools import aqi
from pyecharts import Geo

import pandas as pd

def draw_realtime_aqi_map(time = None):
    
    from opendatatools import aqi
    df_aqi = aqi.get_hour_aqi(time)

    # some city cannot by process by echart
    echart_unsupported_city = [
        "菏泽市", "襄阳市", "恩施州", "湘西州","阿坝州", "延边州",
        "甘孜州", "凉山州", "黔西南州", "黔东南州", "黔南州", "普洱市", "楚雄州", "红河州",
        "文山州", "西双版纳州", "大理州", "德宏州", "怒江州", "迪庆州", "昌都市", "山南市",
        "林芝市", "临夏州", "甘南州", "海北州", "黄南州", "海南州", "果洛州", "玉树州", "海西州",
        "昌吉州", "博州", "克州", "伊犁哈萨克州"]

    if time is None and len(df_aqi) > 0:
        time = df_aqi['time'][0]
    
    data = []
    for index, row in df_aqi.iterrows():
        city = row['city']
        aqi  = row['aqi']

        if city in echart_unsupported_city:
            continue

        data.append( (city, aqi) )

    geo = Geo("全国最新主要城市空气质量（AQI) - %s" % time , "数据来源于环保部网站",
              title_color="#fff",
              title_pos="center", width=1000,
              height=600, background_color='#404a59')

    attr, value = geo.cast(data)

    geo.add("", attr, value, visual_range=[0, 150], 
            maptype='china',visual_text_color="#fff",
            symbol_size=10, is_visualmap=True,
            label_formatter='{b}',             # 指定 label 只显示城市名
            tooltip_formatter='{c}',           # 格式：经度、纬度、值
            label_emphasis_textsize=15,        # 指定标签选中高亮时字体大小
            label_emphasis_pos='right'         # 指定标签选中高亮时字体位置
           )

    return geo

# %%
draw_realtime_aqi_map()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min', 'china': '/nbextensions/echarts-countries-js/china'
#         }
#     });
# </script>
#     <div id="191be860903f429eb4702083a000e59e" style="width:1000px;height:600px;"></div>
#
#
# <script>
#     require(['echarts', 'china'], function(echarts) {
#
# var myChart_191be860903f429eb4702083a000e59e = echarts.init(document.getElementById('191be860903f429eb4702083a000e59e'), 'light', {renderer: 'canvas'});
#
# var option_191be860903f429eb4702083a000e59e = {
#     "title": [
#         {
#             "text": "\u5168\u56fd\u6700\u65b0\u4e3b\u8981\u57ce\u5e02\u7a7a\u6c14\u8d28\u91cf\uff08AQI) - 2018-05-28 13:00:00",
#             "subtext": "\u6570\u636e\u6765\u6e90\u4e8e\u73af\u4fdd\u90e8\u7f51\u7ad9",
#             "left": "center",
#             "top": "auto",
#             "textStyle": {
#                 "color": "#fff",
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "\u4e0b\u8f7d\u56fe\u7247"
#             },
#             "restore": {
#                 "show": true
#             },
#             "dataView": {
#                 "show": true
#             }
#         }
#     },
#     "series_id": 3468461,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "formatter": "{c}",
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "scatter",
#             "coordinateSystem": "geo",
#             "symbol": "circle",
#             "symbolSize": 10,
#             "data": [
#                 {
#                     "name": "\u5317\u4eac\u5e02",
#                     "value": [
#                         116.4,
#                         39.9,
#                         "54"
#                     ]
#                 },
#                 {
#                     "name": "\u5929\u6d25\u5e02",
#                     "value": [
#                         117.2,
#                         39.12,
#                         "153"
#                     ]
#                 },
#                 {
#                     "name": "\u77f3\u5bb6\u5e84\u5e02",
#                     "value": [
#                         114.52,
#                         38.05,
#                         "76"
#                     ]
#                 },
#                 {
#                     "name": "\u5510\u5c71\u5e02",
#                     "value": [
#                         118.2,
#                         39.63,
#                         "147"
#                     ]
#                 },
#                 {
#                     "name": "\u79e6\u7687\u5c9b\u5e02",
#                     "value": [
#                         119.6,
#                         39.93,
#                         "84"
#                     ]
#                 },
#                 {
#                     "name": "\u90af\u90f8\u5e02",
#                     "value": [
#                         114.48,
#                         36.62,
#                         "104"
#                     ]
#                 },
#                 {
#                     "name": "\u90a2\u53f0\u5e02",
#                     "value": [
#                         114.48,
#                         37.07,
#                         "78"
#                     ]
#                 },
#                 {
#                     "name": "\u4fdd\u5b9a\u5e02",
#                     "value": [
#                         115.47,
#                         38.87,
#                         "94"
#                     ]
#                 },
#                 {
#                     "name": "\u627f\u5fb7\u5e02",
#                     "value": [
#                         117.93,
#                         40.97,
#                         "50"
#                     ]
#                 },
#                 {
#                     "name": "\u6ca7\u5dde\u5e02",
#                     "value": [
#                         116.83,
#                         38.3,
#                         "229"
#                     ]
#                 },
#                 {
#                     "name": "\u5eca\u574a\u5e02",
#                     "value": [
#                         116.7,
#                         39.52,
#                         "73"
#                     ]
#                 },
#                 {
#                     "name": "\u8861\u6c34\u5e02",
#                     "value": [
#                         115.68,
#                         37.73,
#                         "124"
#                     ]
#                 },
#                 {
#                     "name": "\u5f20\u5bb6\u53e3\u5e02",
#                     "value": [
#                         114.88,
#                         40.82,
#                         "32"
#                     ]
#                 },
#                 {
#                     "name": "\u592a\u539f\u5e02",
#                     "value": [
#                         112.55,
#                         37.87,
#                         "115"
#                     ]
#                 },
#                 {
#                     "name": "\u5927\u540c\u5e02",
#                     "value": [
#                         113.3,
#                         40.08,
#                         "97"
#                     ]
#                 },
#                 {
#                     "name": "\u9633\u6cc9\u5e02",
#                     "value": [
#                         113.57,
#                         37.85,
#                         "57"
#                     ]
#                 },
#                 {
#                     "name": "\u957f\u6cbb\u5e02",
#                     "value": [
#                         113.12,
#                         36.2,
#                         "69"
#                     ]
#                 },
#                 {
#                     "name": "\u664b\u57ce\u5e02",
#                     "value": [
#                         112.83,
#                         35.5,
#                         "59"
#                     ]
#                 },
#                 {
#                     "name": "\u6714\u5dde\u5e02",
#                     "value": [
#                         112.43,
#                         39.33,
#                         "71"
#                     ]
#                 },
#                 {
#                     "name": "\u664b\u4e2d\u5e02",
#                     "value": [
#                         112.75,
#                         37.68,
#                         "105"
#                     ]
#                 },
#                 {
#                     "name": "\u8fd0\u57ce\u5e02",
#                     "value": [
#                         110.98,
#                         35.02,
#                         "101"
#                     ]
#                 },
#                 {
#                     "name": "\u5ffb\u5dde\u5e02",
#                     "value": [
#                         112.73,
#                         38.42,
#                         "78"
#                     ]
#                 },
#                 {
#                     "name": "\u4e34\u6c7e\u5e02",
#                     "value": [
#                         111.52,
#                         36.08,
#                         "125"
#                     ]
#                 },
#                 {
#                     "name": "\u5415\u6881\u5e02",
#                     "value": [
#                         111.13,
#                         37.52,
#                         "65"
#                     ]
#                 },
#                 {
#                     "name": "\u547c\u548c\u6d69\u7279\u5e02",
#                     "value": [
#                         111.73,
#                         40.83,
#                         "34"
#                     ]
#                 },
#                 {
#                     "name": "\u5305\u5934\u5e02",
#                     "value": [
#                         109.83,

# %% [markdown]
# ## Case 3: 获取历史某日全国AQI数据并画地图展示

# %%
# encoding: utf-8

from opendatatools import aqi
from pyecharts import Geo

import pandas as pd


def draw_his_aqi_map(date):
    
    from opendatatools import aqi
    df_aqi = aqi.get_daily_aqi(date)
    #df_aqi.to_csv("aqi_daily.csv")

    # some city cannot by process by echart
    echart_unsupported_city = [
        "菏泽市", "襄阳市", "恩施州", "湘西州","阿坝州", "延边州",
        "甘孜州", "凉山州", "黔西南州", "黔东南州", "黔南州", "普洱市", "楚雄州", "红河州",
        "文山州", "西双版纳州", "大理州", "德宏州", "怒江州", "迪庆州", "昌都市", "山南市",
        "林芝市", "临夏州", "甘南州", "海北州", "黄南州", "海南州", "果洛州", "玉树州", "海西州",
        "昌吉州", "博州", "克州", "伊犁哈萨克州"]

    data = []
    for index, row in df_aqi.iterrows():
        city = row['city']
        aqi  = row['aqi']

        if city in echart_unsupported_city:
            continue

        data.append( (city, aqi) )

    geo = Geo("全国主要城市空气质量（AQI) - %s" % date , "数据来源于环保部网站",
              title_color="#fff",
              title_pos="center", width=1000,
              height=600, background_color='#404a59')

    attr, value = geo.cast(data)

    geo.add("", attr, value, visual_range=[0, 150], 
            maptype='china',visual_text_color="#fff",
            symbol_size=10, is_visualmap=True,
            label_formatter='{b}',             # 指定 label 只显示城市名
            tooltip_formatter='{c}',           # 格式：经度、纬度、值
            label_emphasis_textsize=15,        # 指定标签选中高亮时字体大小
            label_emphasis_pos='right'         # 指定标签选中高亮时字体位置
           )

    return geo
# Out:
#   File "<ipython-input-74-6549a965af95>", line 43
#     label_formatter='{b}',             # 指定 label 只显示城市名
#                   ^
# SyntaxError: invalid syntax

# %%
draw_his_aqi_map('2018-05-27')
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min', 'china': '/nbextensions/echarts-countries-js/china'
#         }
#     });
# </script>
#     <div id="fea1f6fe3e6f4c7283f33e3c0bf94008" style="width:1000px;height:600px;"></div>
#
#
# <script>
#     require(['echarts', 'china'], function(echarts) {
#
# var myChart_fea1f6fe3e6f4c7283f33e3c0bf94008 = echarts.init(document.getElementById('fea1f6fe3e6f4c7283f33e3c0bf94008'), 'light', {renderer: 'canvas'});
#
# var option_fea1f6fe3e6f4c7283f33e3c0bf94008 = {
#     "title": [
#         {
#             "text": "\u5168\u56fd\u4e3b\u8981\u57ce\u5e02\u7a7a\u6c14\u8d28\u91cf\uff08AQI) - 2018-05-27",
#             "subtext": "\u6570\u636e\u6765\u6e90\u4e8e\u73af\u4fdd\u90e8\u7f51\u7ad9",
#             "left": "center",
#             "top": "auto",
#             "textStyle": {
#                 "color": "#fff",
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "\u4e0b\u8f7d\u56fe\u7247"
#             },
#             "restore": {
#                 "show": true
#             },
#             "dataView": {
#                 "show": true
#             }
#         }
#     },
#     "series_id": 6233033,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "formatter": "{b}: {c}",
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "scatter",
#             "coordinateSystem": "geo",
#             "symbol": "circle",
#             "symbolSize": 10,
#             "data": [
#                 {
#                     "name": "\u5317\u4eac\u5e02",
#                     "value": [
#                         116.4,
#                         39.9,
#                         "90"
#                     ]
#                 },
#                 {
#                     "name": "\u5929\u6d25\u5e02",
#                     "value": [
#                         117.2,
#                         39.12,
#                         "99"
#                     ]
#                 },
#                 {
#                     "name": "\u77f3\u5bb6\u5e84\u5e02",
#                     "value": [
#                         114.52,
#                         38.05,
#                         "89"
#                     ]
#                 },
#                 {
#                     "name": "\u5510\u5c71\u5e02",
#                     "value": [
#                         118.2,
#                         39.63,
#                         "104"
#                     ]
#                 },
#                 {
#                     "name": "\u79e6\u7687\u5c9b\u5e02",
#                     "value": [
#                         119.6,
#                         39.93,
#                         "95"
#                     ]
#                 },
#                 {
#                     "name": "\u90af\u90f8\u5e02",
#                     "value": [
#                         114.48,
#                         36.62,
#                         "101"
#                     ]
#                 },
#                 {
#                     "name": "\u90a2\u53f0\u5e02",
#                     "value": [
#                         114.48,
#                         37.07,
#                         "88"
#                     ]
#                 },
#                 {
#                     "name": "\u4fdd\u5b9a\u5e02",
#                     "value": [
#                         115.47,
#                         38.87,
#                         "97"
#                     ]
#                 },
#                 {
#                     "name": "\u627f\u5fb7\u5e02",
#                     "value": [
#                         117.93,
#                         40.97,
#                         "82"
#                     ]
#                 },
#                 {
#                     "name": "\u6ca7\u5dde\u5e02",
#                     "value": [
#                         116.83,
#                         38.3,
#                         "100"
#                     ]
#                 },
#                 {
#                     "name": "\u5eca\u574a\u5e02",
#                     "value": [
#                         116.7,
#                         39.52,
#                         "84"
#                     ]
#                 },
#                 {
#                     "name": "\u8861\u6c34\u5e02",
#                     "value": [
#                         115.68,
#                         37.73,
#                         "90"
#                     ]
#                 },
#                 {
#                     "name": "\u5f20\u5bb6\u53e3\u5e02",
#                     "value": [
#                         114.88,
#                         40.82,
#                         "203"
#                     ]
#                 },
#                 {
#                     "name": "\u592a\u539f\u5e02",
#                     "value": [
#                         112.55,
#                         37.87,
#                         "117"
#                     ]
#                 },
#                 {
#                     "name": "\u5927\u540c\u5e02",
#                     "value": [
#                         113.3,
#                         40.08,
#                         "87"
#                     ]
#                 },
#                 {
#                     "name": "\u9633\u6cc9\u5e02",
#                     "value": [
#                         113.57,
#                         37.85,
#                         "90"
#                     ]
#                 },
#                 {
#                     "name": "\u957f\u6cbb\u5e02",
#                     "value": [
#                         113.12,
#                         36.2,
#                         "90"
#                     ]
#                 },
#                 {
#                     "name": "\u664b\u57ce\u5e02",
#                     "value": [
#                         112.83,
#                         35.5,
#                         "95"
#                     ]
#                 },
#                 {
#                     "name": "\u6714\u5dde\u5e02",
#                     "value": [
#                         112.43,
#                         39.33,
#                         "87"
#                     ]
#                 },
#                 {
#                     "name": "\u664b\u4e2d\u5e02",
#                     "value": [
#                         112.75,
#                         37.68,
#                         "108"
#                     ]
#                 },
#                 {
#                     "name": "\u8fd0\u57ce\u5e02",
#                     "value": [
#                         110.98,
#                         35.02,
#                         "98"
#                     ]
#                 },
#                 {
#                     "name": "\u5ffb\u5dde\u5e02",
#                     "value": [
#                         112.73,
#                         38.42,
#                         "76"
#                     ]
#                 },
#                 {
#                     "name": "\u4e34\u6c7e\u5e02",
#                     "value": [
#                         111.52,
#                         36.08,
#                         "110"
#                     ]
#                 },
#                 {
#                     "name": "\u5415\u6881\u5e02",
#                     "value": [
#                         111.13,
#                         37.52,
#                         "73"
#                     ]
#                 },
#                 {
#                     "name": "\u547c\u548c\u6d69\u7279\u5e02",
#                     "value": [
#                         111.73,
#                         40.83,
#                         "88"
#                     ]
#                 },
#                 {
#                     "name": "\u5305\u5934\u5e02",
#                     "value": [
#                         109.83,
#                         40.65,

# %%
draw_his_aqi_map('2017-05-27')
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min', 'china': '/nbextensions/echarts-countries-js/china'
#         }
#     });
# </script>
#     <div id="96153e4e63974563938baeb119150131" style="width:1000px;height:600px;"></div>
#
#
# <script>
#     require(['echarts', 'china'], function(echarts) {
#
# var myChart_96153e4e63974563938baeb119150131 = echarts.init(document.getElementById('96153e4e63974563938baeb119150131'), 'light', {renderer: 'canvas'});
#
# var option_96153e4e63974563938baeb119150131 = {
#     "title": [
#         {
#             "text": "\u5168\u56fd\u4e3b\u8981\u57ce\u5e02\u7a7a\u6c14\u8d28\u91cf\uff08AQI) - 2017-05-27",
#             "subtext": "\u6570\u636e\u6765\u6e90\u4e8e\u73af\u4fdd\u90e8\u7f51\u7ad9",
#             "left": "center",
#             "top": "auto",
#             "textStyle": {
#                 "color": "#fff",
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "\u4e0b\u8f7d\u56fe\u7247"
#             },
#             "restore": {
#                 "show": true
#             },
#             "dataView": {
#                 "show": true
#             }
#         }
#     },
#     "series_id": 4517191,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "formatter": "{b}: {c}",
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "scatter",
#             "coordinateSystem": "geo",
#             "symbol": "circle",
#             "symbolSize": 10,
#             "data": [
#                 {
#                     "name": "\u5317\u4eac\u5e02",
#                     "value": [
#                         116.4,
#                         39.9,
#                         "191"
#                     ]
#                 },
#                 {
#                     "name": "\u5929\u6d25\u5e02",
#                     "value": [
#                         117.2,
#                         39.12,
#                         "159"
#                     ]
#                 },
#                 {
#                     "name": "\u77f3\u5bb6\u5e84\u5e02",
#                     "value": [
#                         114.52,
#                         38.05,
#                         "202"
#                     ]
#                 },
#                 {
#                     "name": "\u5510\u5c71\u5e02",
#                     "value": [
#                         118.2,
#                         39.63,
#                         "121"
#                     ]
#                 },
#                 {
#                     "name": "\u79e6\u7687\u5c9b\u5e02",
#                     "value": [
#                         119.6,
#                         39.93,
#                         "115"
#                     ]
#                 },
#                 {
#                     "name": "\u90af\u90f8\u5e02",
#                     "value": [
#                         114.48,
#                         36.62,
#                         "176"
#                     ]
#                 },
#                 {
#                     "name": "\u90a2\u53f0\u5e02",
#                     "value": [
#                         114.48,
#                         37.07,
#                         "202"
#                     ]
#                 },
#                 {
#                     "name": "\u4fdd\u5b9a\u5e02",
#                     "value": [
#                         115.47,
#                         38.87,
#                         "206"
#                     ]
#                 },
#                 {
#                     "name": "\u5f20\u5bb6\u53e3\u5e02",
#                     "value": [
#                         114.88,
#                         40.82,
#                         "150"
#                     ]
#                 },
#                 {
#                     "name": "\u627f\u5fb7\u5e02",
#                     "value": [
#                         117.93,
#                         40.97,
#                         "187"
#                     ]
#                 },
#                 {
#                     "name": "\u6ca7\u5dde\u5e02",
#                     "value": [
#                         116.83,
#                         38.3,
#                         "206"
#                     ]
#                 },
#                 {
#                     "name": "\u5eca\u574a\u5e02",
#                     "value": [
#                         116.7,
#                         39.52,
#                         "189"
#                     ]
#                 },
#                 {
#                     "name": "\u8861\u6c34\u5e02",
#                     "value": [
#                         115.68,
#                         37.73,
#                         "201"
#                     ]
#                 },
#                 {
#                     "name": "\u5f20\u5bb6\u53e3\u5e02",
#                     "value": [
#                         114.88,
#                         40.82,
#                         "150"
#                     ]
#                 },
#                 {
#                     "name": "\u592a\u539f\u5e02",
#                     "value": [
#                         112.55,
#                         37.87,
#                         "148"
#                     ]
#                 },
#                 {
#                     "name": "\u5927\u540c\u5e02",
#                     "value": [
#                         113.3,
#                         40.08,
#                         "85"
#                     ]
#                 },
#                 {
#                     "name": "\u9633\u6cc9\u5e02",
#                     "value": [
#                         113.57,
#                         37.85,
#                         "141"
#                     ]
#                 },
#                 {
#                     "name": "\u957f\u6cbb\u5e02",
#                     "value": [
#                         113.12,
#                         36.2,
#                         "146"
#                     ]
#                 },
#                 {
#                     "name": "\u664b\u57ce\u5e02",
#                     "value": [
#                         112.83,
#                         35.5,
#                         "163"
#                     ]
#                 },
#                 {
#                     "name": "\u6714\u5dde\u5e02",
#                     "value": [
#                         112.43,
#                         39.33,
#                         "90"
#                     ]
#                 },
#                 {
#                     "name": "\u664b\u4e2d\u5e02",
#                     "value": [
#                         112.75,
#                         37.68,
#                         "155"
#                     ]
#                 },
#                 {
#                     "name": "\u8fd0\u57ce\u5e02",
#                     "value": [
#                         110.98,
#                         35.02,
#                         "141"
#                     ]
#                 },
#                 {
#                     "name": "\u5ffb\u5dde\u5e02",
#                     "value": [
#                         112.73,
#                         38.42,
#                         "141"
#                     ]
#                 },
#                 {
#                     "name": "\u4e34\u6c7e\u5e02",
#                     "value": [
#                         111.52,
#                         36.08,
#                         "177"
#                     ]
#                 },
#                 {
#                     "name": "\u5415\u6881\u5e02",
#                     "value": [
#                         111.13,
#                         37.52,
#                         "98"
#                     ]
#                 },
#                 {
#                     "name": "\u547c\u548c\u6d69\u7279\u5e02",
#                     "value": [
#                         111.73,

# %%
draw_his_aqi_map('2016-05-27')
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min', 'china': '/nbextensions/echarts-countries-js/china'
#         }
#     });
# </script>
#     <div id="99243d269e8646f296f787386164a3cb" style="width:1000px;height:600px;"></div>
#
#
# <script>
#     require(['echarts', 'china'], function(echarts) {
#
# var myChart_99243d269e8646f296f787386164a3cb = echarts.init(document.getElementById('99243d269e8646f296f787386164a3cb'), 'light', {renderer: 'canvas'});
#
# var option_99243d269e8646f296f787386164a3cb = {
#     "title": [
#         {
#             "text": "\u5168\u56fd\u4e3b\u8981\u57ce\u5e02\u7a7a\u6c14\u8d28\u91cf\uff08AQI) - 2016-05-27",
#             "subtext": "\u6570\u636e\u6765\u6e90\u4e8e\u73af\u4fdd\u90e8\u7f51\u7ad9",
#             "left": "center",
#             "top": "auto",
#             "textStyle": {
#                 "color": "#fff",
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "\u4e0b\u8f7d\u56fe\u7247"
#             },
#             "restore": {
#                 "show": true
#             },
#             "dataView": {
#                 "show": true
#             }
#         }
#     },
#     "series_id": 6004607,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "formatter": "{b}: {c}",
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "scatter",
#             "coordinateSystem": "geo",
#             "symbol": "circle",
#             "symbolSize": 10,
#             "data": [
#                 {
#                     "name": "\u5317\u4eac\u5e02",
#                     "value": [
#                         116.4,
#                         39.9,
#                         "122"
#                     ]
#                 },
#                 {
#                     "name": "\u5929\u6d25\u5e02",
#                     "value": [
#                         117.2,
#                         39.12,
#                         "95"
#                     ]
#                 },
#                 {
#                     "name": "\u77f3\u5bb6\u5e84\u5e02",
#                     "value": [
#                         114.52,
#                         38.05,
#                         "77"
#                     ]
#                 },
#                 {
#                     "name": "\u5510\u5c71\u5e02",
#                     "value": [
#                         118.2,
#                         39.63,
#                         "110"
#                     ]
#                 },
#                 {
#                     "name": "\u79e6\u7687\u5c9b\u5e02",
#                     "value": [
#                         119.6,
#                         39.93,
#                         "96"
#                     ]
#                 },
#                 {
#                     "name": "\u90af\u90f8\u5e02",
#                     "value": [
#                         114.48,
#                         36.62,
#                         "92"
#                     ]
#                 },
#                 {
#                     "name": "\u90a2\u53f0\u5e02",
#                     "value": [
#                         114.48,
#                         37.07,
#                         "87"
#                     ]
#                 },
#                 {
#                     "name": "\u4fdd\u5b9a\u5e02",
#                     "value": [
#                         115.47,
#                         38.87,
#                         "98"
#                     ]
#                 },
#                 {
#                     "name": "\u5f20\u5bb6\u53e3\u5e02",
#                     "value": [
#                         114.88,
#                         40.82,
#                         "99"
#                     ]
#                 },
#                 {
#                     "name": "\u627f\u5fb7\u5e02",
#                     "value": [
#                         117.93,
#                         40.97,
#                         "127"
#                     ]
#                 },
#                 {
#                     "name": "\u6ca7\u5dde\u5e02",
#                     "value": [
#                         116.83,
#                         38.3,
#                         "88"
#                     ]
#                 },
#                 {
#                     "name": "\u5eca\u574a\u5e02",
#                     "value": [
#                         116.7,
#                         39.52,
#                         "90"
#                     ]
#                 },
#                 {
#                     "name": "\u8861\u6c34\u5e02",
#                     "value": [
#                         115.68,
#                         37.73,
#                         "76"
#                     ]
#                 },
#                 {
#                     "name": "\u592a\u539f\u5e02",
#                     "value": [
#                         112.55,
#                         37.87,
#                         "87"
#                     ]
#                 },
#                 {
#                     "name": "\u5927\u540c\u5e02",
#                     "value": [
#                         113.3,
#                         40.08,
#                         "96"
#                     ]
#                 },
#                 {
#                     "name": "\u9633\u6cc9\u5e02",
#                     "value": [
#                         113.57,
#                         37.85,
#                         "87"
#                     ]
#                 },
#                 {
#                     "name": "\u957f\u6cbb\u5e02",
#                     "value": [
#                         113.12,
#                         36.2,
#                         "59"
#                     ]
#                 },
#                 {
#                     "name": "\u664b\u57ce\u5e02",
#                     "value": [
#                         112.83,
#                         35.5,
#                         "44"
#                     ]
#                 },
#                 {
#                     "name": "\u6714\u5dde\u5e02",
#                     "value": [
#                         112.43,
#                         39.33,
#                         "94"
#                     ]
#                 },
#                 {
#                     "name": "\u664b\u4e2d\u5e02",
#                     "value": [
#                         112.75,
#                         37.68,
#                         "92"
#                     ]
#                 },
#                 {
#                     "name": "\u8fd0\u57ce\u5e02",
#                     "value": [
#                         110.98,
#                         35.02,
#                         "58"
#                     ]
#                 },
#                 {
#                     "name": "\u5ffb\u5dde\u5e02",
#                     "value": [
#                         112.73,
#                         38.42,
#                         "87"
#                     ]
#                 },
#                 {
#                     "name": "\u4e34\u6c7e\u5e02",
#                     "value": [
#                         111.52,
#                         36.08,
#                         "70"
#                     ]
#                 },
#                 {
#                     "name": "\u5415\u6881\u5e02",
#                     "value": [
#                         111.13,
#                         37.52,
#                         "55"
#                     ]
#                 },
#                 {
#                     "name": "\u547c\u548c\u6d69\u7279\u5e02",
#                     "value": [
#                         111.73,
#                         40.83,
#                         "102"
#                     ]
#                 },
#                 {
#                     "name": "\u5305\u5934\u5e02",
#                     "value": [
#                         109.83,
#                         40.65,

# %% [markdown]
# ## Case 4 : 看某几个城市历史一段时间的走势图

# %%
# encoding: utf-8

from pyecharts import Line
import pandas as pd

def draw_city_aqi(cities, start_date = None, end_date = None):
    from opendatatools import aqi
    line = Line("城市AQI趋势图")
    
    data_dict = {}
    for city in cities:
        print("getting data for %s" % city)
        df_aqi = aqi.get_daily_aqi_onecity(city)
        df_aqi.set_index('date', inplace=True)
        df_aqi.sort_index(ascending=True, inplace=True)

        if start_date is not None:
            df_aqi = df_aqi[df_aqi.index >= start_date]
        
        if end_date is not None:
            df_aqi = df_aqi[df_aqi.index <= end_date]
        
        
        data_dict[city] = df_aqi
    
        axis_x = df_aqi.index
        axis_y = df_aqi['aqi']

        line.add("aqi curve for %s" % (city), axis_x, axis_y, mark_point=["average"])

    return line

# %%
draw_city_aqi(['北京市','上海市'], start_date = '2018-01-01', end_date = '2018-05-31')
# Out:
# getting data for 北京市
# getting data for 上海市
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="29014c243a2e45149fbfa03732f67b4e" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_29014c243a2e45149fbfa03732f67b4e = echarts.init(document.getElementById('29014c243a2e45149fbfa03732f67b4e'), 'light', {renderer: 'canvas'});
#
# var option_29014c243a2e45149fbfa03732f67b4e = {
#     "title": [
#         {
#             "text": "\u57ce\u5e02AQI\u8d8b\u52bf\u56fe",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "\u4e0b\u8f7d\u56fe\u7247"
#             },
#             "restore": {
#                 "show": true
#             },
#             "dataView": {
#                 "show": true
#             }
#         }
#     },
#     "series_id": 5001561,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "line",
#             "name": "aqi curve for \u5317\u4eac\u5e02",
#             "symbol": "emptyCircle",
#             "symbolSize": 4,
#             "smooth": false,
#             "step": false,
#             "showSymbol": true,
#             "data": [
#                 59.0,
#                 48.0,
#                 29.0,
#                 45.0,
#                 68.0,
#                 52.0,
#                 59.0,
#                 55.0,
#                 35.0,
#                 34.0,
#                 34.0,
#                 94.0,
#                 135.0,
#                 175.0,
#                 64.0,
#                 114.0,
#                 76.0,
#                 100.0,
#                 104.0,
#                 65.0,
#                 64.0,
#                 50.0,
#                 33.0,
#                 40.0,
#                 37.0,
#                 58.0,
#                 108.0,
#                 57.0,
#                 55.0,
#                 37.0,
#                 62.0,
#                 67.0,
#                 37.0,
#                 36.0,
#                 44.0,
#                 37.0,
#                 72.0,
#                 50.0,
#                 73.0,
#                 79.0,
#                 43.0,
#                 66.0,
#                 52.0,
#                 80.0,
#                 40.0,
#                 73.0,
#                 105.0,
#                 110.0,
#                 152.0,
#                 188.0,
#                 64.0,
#                 48.0,
#                 46.0,
#                 53.0,
#                 62.0,
#                 82.0,
#                 165.0,
#                 219.0,
#                 117.0,
#                 50.0,
#                 105.0,
#                 221.0,
#                 129.0,
#                 90.0,
#                 63.0,
#                 65.0,
#                 63.0,
#                 138.0,
#                 156.0,
#                 87.0,
#                 195.0,
#                 294.0,
#                 288.0,
#                 54.0,
#                 56.0,
#                 83.0,
#                 138.0,
#                 94.0,
#                 46.0,
#                 80.0,
#                 114.0,
#                 144.0,
#                 120.0,
#                 78.0,
#                 160.0,
#                 249.0,
#                 500.0,
#                 110.0,
#                 69.0,
#                 134.0,
#                 226.0,
#                 272.0,
#                 44.0,
#                 43.0,
#                 136.0,
#                 58.0,
#                 51.0,
#                 69.0,
#                 115.0,
#                 84.0,
#                 55.0,
#                 79.0,
#                 69.0,
#                 128.0,
#                 66.0,
#                 106.0,
#                 133.0,
#                 143.0,
#                 159.0,
#                 165.0,
#                 89.0,
#                 38.0,
#                 55.0,
#                 65.0,
#                 87.0,
#                 120.0,
#                 110.0,
#                 150.0,
#                 204.0,
#                 69.0,
#                 117.0,
#                 51.0,
#                 58.0,
#                 120.0,
#                 104.0,
#                 91.0,
#                 120.0,
#                 146.0,
#                 108.0,
#                 185.0,
#                 119.0,
#                 178.0,
#                 92.0,
#                 150.0,
#                 59.0,
#                 94.0,
#                 110.0,
#                 63.0,
#                 83.0,
#                 135.0,
#                 138.0,
#                 151.0,
#                 162.0,
#                 133.0,
#                 90.0
#             ],
#             "label": {
#                 "normal": {
#                     "show": false,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "lineStyle": {
#                 "normal": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "areaStyle": {
#                 "opacity": 0
#             },
#             "markPoint": {
#                 "data": [
#                     {
#                         "type": "average",
#                         "name": "mean-Value",
#                         "symbol": "pin",
#                         "symbolSize": 50,
#                         "label": {
#                             "normal": {
#                                 "textStyle": {
#                                     "color": "#fff"
#                                 }
#                             }
#                         }
#                     }
#                 ]
#             },
#             "markLine": {
#                 "data": []
#             },
#             "seriesId": 5001561
#         },
#         {
#             "type": "line",
#             "name": "aqi curve for \u4e0a\u6d77\u5e02",
#             "symbol": "emptyCircle",
#             "symbolSize": 4,
#             "smooth": false,
#             "step": false,
#             "showSymbol": true,
#             "data": [
#                 123.0,
#                 59.0,
#                 42.0,
#                 37.0,
#                 52.0,
#                 79.0,
#                 67.0,
#                 124.0,
#                 62.0,
#                 72.0,
#                 77.0,
#                 75.0,
#                 106.0,
#                 84.0,
#                 99.0,
#                 98.0,
#                 137.0,
#                 105.0,
#                 163.0,
#                 113.0,
#                 74.0,
#                 88.0,
#                 112.0,
#                 40.0,
#                 43.0,
#                 35.0,
#                 52.0,
#                 43.0,
#                 127.0,
#                 239.0,
#                 223.0,
#                 162.0,
#                 135.0,
#                 42.0,
#                 53.0,
#                 94.0,
#                 65.0,
#                 84.0,
#                 112.0,
#                 88.0,
#                 89.0,
#                 96.0,
#                 87.0,
#                 65.0,
#                 75.0,
#                 52.0,
#                 39.0,
#                 68.0,
#                 45.0,
#                 50.0,
#                 59.0,
#                 49.0,
#                 65.0,
#                 69.0,

# %% [markdown]
# ## Case 5 : 看某个城市日内小时走势图

# %%
from pyecharts import Line
import pandas as pd

def draw_city_aqi_hour(cities, date):
    from opendatatools import aqi
    line = Line("城市AQI小时趋势图")
    
    data_dict = {}
    for city in cities:
        print("getting data for %s" % city)
        df_aqi = aqi.get_hour_aqi_onecity(city, date)
        df_aqi.set_index('time', inplace=True)
        df_aqi.sort_index(ascending=True, inplace=True)

        data_dict[city] = df_aqi
    
        axis_x = df_aqi.index
        axis_y = df_aqi['aqi']

        line.add("aqi curve for %s" % (city), axis_x, axis_y, mark_point=["average"])

    return line

# %%
draw_city_aqi_hour(['北京市', '上海市'], '2018-05-28')
# Out:
# getting data for 北京市
# getting data for 上海市
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="88aacdee16324edcaf8dfee769dfadad" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_88aacdee16324edcaf8dfee769dfadad = echarts.init(document.getElementById('88aacdee16324edcaf8dfee769dfadad'), 'light', {renderer: 'canvas'});
#
# var option_88aacdee16324edcaf8dfee769dfadad = {
#     "title": [
#         {
#             "text": "\u57ce\u5e02AQI\u5c0f\u65f6\u8d8b\u52bf\u56fe",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "\u4e0b\u8f7d\u56fe\u7247"
#             },
#             "restore": {
#                 "show": true
#             },
#             "dataView": {
#                 "show": true
#             }
#         }
#     },
#     "series_id": 4552984,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "line",
#             "name": "aqi curve for \u5317\u4eac\u5e02",
#             "symbol": "emptyCircle",
#             "symbolSize": 4,
#             "smooth": false,
#             "step": false,
#             "showSymbol": true,
#             "data": [
#                 97.0,
#                 101.0,
#                 122.0,
#                 388.0,
#                 500.0,
#                 500.0,
#                 500.0,
#                 500.0,
#                 469.0,
#                 440.0,
#                 178.0,
#                 96.0
#             ],
#             "label": {
#                 "normal": {
#                     "show": false,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "lineStyle": {
#                 "normal": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "areaStyle": {
#                 "opacity": 0
#             },
#             "markPoint": {
#                 "data": [
#                     {
#                         "type": "average",
#                         "name": "mean-Value",
#                         "symbol": "pin",
#                         "symbolSize": 50,
#                         "label": {
#                             "normal": {
#                                 "textStyle": {
#                                     "color": "#fff"
#                                 }
#                             }
#                         }
#                     }
#                 ]
#             },
#             "markLine": {
#                 "data": []
#             },
#             "seriesId": 4552984
#         },
#         {
#             "type": "line",
#             "name": "aqi curve for \u4e0a\u6d77\u5e02",
#             "symbol": "emptyCircle",
#             "symbolSize": 4,
#             "smooth": false,
#             "step": false,
#             "showSymbol": true,
#             "data": [
#                 72.0,
#                 79.0,
#                 84.0,
#                 82.0,
#                 84.0,
#                 87.0,
#                 89.0,
#                 93.0,
#                 114.0,
#                 132.0,
#                 118.0,
#                 104.0
#             ],
#             "label": {
#                 "normal": {
#                     "show": false,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "lineStyle": {
#                 "normal": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "areaStyle": {
#                 "opacity": 0
#             },
#             "markPoint": {
#                 "data": [
#                     {
#                         "type": "average",
#                         "name": "mean-Value",
#                         "symbol": "pin",
#                         "symbolSize": 50,
#                         "label": {
#                             "normal": {
#                                 "textStyle": {
#                                     "color": "#fff"
#                                 }
#                             }
#                         }
#                     }
#                 ]
#             },
#             "markLine": {
#                 "data": []
#             },
#             "seriesId": 4552984
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "aqi curve for \u5317\u4eac\u5e02",
#                 "aqi curve for \u4e0a\u6d77\u5e02"
#             ],
#             "selectedMode": "multiple",
#             "show": true,
#             "left": "center",
#             "top": "top",
#             "orient": "horizontal",
#             "textStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "xAxis": [
#         {
#             "show": true,
#             "nameLocation": "middle",
#             "nameGap": 25,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "boundaryGap": true,
#             "type": "category",
#             "splitLine": {
#                 "show": false
#             },
#             "axisLabel": {
#                 "interval": "auto",
#                 "rotate": 0,
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 12
#                 }
#             },
#             "data": [
#                 "2018-05-28 00:00:00",
#                 "2018-05-28 01:00:00",
#                 "2018-05-28 02:00:00",
#                 "2018-05-28 03:00:00",
#                 "2018-05-28 04:00:00",
#                 "2018-05-28 05:00:00",
#                 "2018-05-28 06:00:00",
#                 "2018-05-28 07:00:00",
#                 "2018-05-28 08:00:00",
#                 "2018-05-28 09:00:00",
#                 "2018-05-28 10:00:00",
#                 "2018-05-28 11:00:00"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "nameLocation": "middle",
#             "nameGap": 25,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "boundaryGap": true,
#             "type": "value",
#             "splitLine": {
#                 "show": true
#             },
#             "axisLabel": {
#                 "interval": "auto",
#                 "formatter": "{value} ",
#                 "rotate": 0,
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 12
#                 }
#             }
#         }
#     ],
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#5
